# %% [markdown]
# ## Correlation testing

# %%
import os 
os.getcwd()

# %%
os.chdir("C:/Users/User/Desktop/project")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\project'

# %%
import pandas as pd 

df = pd.read_csv("general_data.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.Attrition = df.Attrition.map({"Yes" : 1, "No" : 0}) 
df.Gender = df.Gender.map({'Male' : 1, 'Female' : 0})

# %%
df1 = df.dropna()

# %% [markdown]
# __Correlation Matrix__

# %%
df1.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.158399          0.007376  -0.033900
# Attrition               -0.158399   1.000000         -0.009449  -0.017106
# DistanceFromHome         0.007376  -0.009449          1.000000  -0.007491
# Education               -0.033900  -0.017106         -0.007491   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008105  -0.004621         -0.000326  -0.009389
# Gender                  -0.040625   0.018396         -0.042610  -0.017671
# JobLevel                -0.001137  -0.012382         -0.039990   0.045822
# MonthlyIncome           -0.045163  -0.030160         -0.022757   0.007289
# NumCompaniesWorked       0.299527   0.042831         -0.014449  -0.016210
# PercentSalaryHike       -0.032561   0.033153          0.037720  -0.041054
# StandardHours                 NaN        NaN               NaN        NaN
# ...

# %% [markdown]
# __Correlation coefficient between Attrition and Age__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.Age)

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.15839867954096148
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and DistanceFromHome__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.DistanceFromHome)

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.009448638515156127
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and Education__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.Education) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.01710630705027809
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and Gender__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.Gender) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : 0.018396425194440544
# Hence they are positively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and JobLevel__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.JobLevel) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.012381569720790162
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and MonthlyIncome__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.MonthlyIncome) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.030160293808459582
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and PercentSalaryHike__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.PercentSalaryHike) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : 0.033153037135465274
# Hence they are positively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and StockOptionLevel__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.StockOptionLevel) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.008164026684984015
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and TotalWorkingYears__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.TotalWorkingYears) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.16966991684723276
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and YearsAtCompany__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.YearsAtCompany) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.13300261842521066
# Hence they are negatively correlated

# %% [markdown]
# __Correlation coefficient between Attrition and YearsWithCurrManager__

# %%
from scipy.stats import pearsonr 
stats,p = pearsonr(df1.Attrition,df1.YearsWithCurrManager) 

print('the value of correlation co-efficient :',stats)
if stats < 0:
    print("Hence they are negatively correlated")
elif stats > 0:
    print('Hence they are positively correlated')
elif stats == 0:
    print('Hence they are not correlated')
# Out:
# the value of correlation co-efficient : -0.15469153690286755
# Hence they are negatively correlated
